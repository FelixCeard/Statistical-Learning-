# %%
import numpy as np
from typing import List, Tuple
from scipy.stats import norm
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from enum import Enum
from scipy import stats
import seaborn as sns

from scipy.stats import binom
from scipy.special import comb

# %% [markdown]
# # Implementation of the given formulas
# Note that the fs array (the array containing the value of all the $f_i$) is starting at $f_1$, i.e., fs = [$f_1, f_2, \dots, f_N$].

# %%
def compute_f0(fs: List[int]):
    if fs[1] == 0:
        return (fs[0] * (fs[0] - 1)) / (2 * (fs[1]+1))
    return (fs[0]**2) / (2*fs[1])

# %%
def compute_variance(fs: List[int], Nhat: float):
    if fs[1] == 0:
        return (
            ((fs[0] * (fs[0] - 1)) / 2) + \
            ((fs[0]*((2.0*fs[0]-1)**2))/4) - \
            ((fs[0]**4)/Nhat)
        )
    # print('B')
    return (
        fs[1] * (
            (1/4)*((fs[0]/fs[1])**4) + \
            (fs[0]/fs[1])**3 + \
            ((1/2) * ((fs[0] / fs[1])**2))
        )
    )

# %%
def compute_confidence_inverval(n:int, f0_hat:float, variance:float, alpha:float) -> Tuple[float, float]:
    """
    Computes the 100(1-alpha)% confidence interval for N 
    """
    z_alpha = norm.ppf(1-(alpha/2))
    if f0_hat < 1e-10:
        # f0_hat = 
        Q = np.inf
    else:
        Q = np.exp(z_alpha * np.sqrt(np.log(1+((variance)/(f0_hat**2)))))
    return (
        n + (f0_hat / Q),
        n + (f0_hat * Q)
    )

# %%
def compute_fs(num_caught: np.ndarray, T: int):
    fs = np.zeros(T-1)
    for t in range(1, T):
        fs[t-1] = np.sum(num_caught == t)
    return fs.tolist()

# %%
class PROBABILITY_DISTIRBUTIONS(Enum):
    UNIFORM_001 = 1
    UNIFORM_002 = 2
    BETA_13 = 3
    BETA_22 = 4

# %% [markdown]
# # Simulation --- Single Run

# %%
N = 1000
T = 40
alpha = 0.01
np.random.seed(0)

def simulate_with_history(N: int, T: int, probability_distribution: PROBABILITY_DISTIRBUTIONS, alpha=0.05, verbose: bool = True):
    num_caught = np.zeros(N)

    history_N_hat = []
    history_variance = []
    history_f0_hat = []
    history_true_f0 = []
    history_confidence_interval = []
    is_withing_range = []
    # last_step_in_range = []
    value_of_f2 = []


    for t in tqdm(range(T), desc="Simulating...", disable=not verbose):

        if probability_distribution == PROBABILITY_DISTIRBUTIONS.UNIFORM_001:
            # uniform U(0.0, 0.01)
            probability_caught = np.random.uniform(0, 0.01, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.UNIFORM_002:
            # # uniform U(0.0, 0.02)
            probability_caught = np.random.uniform(0, 0.02, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.BETA_13:
            # # beta distribution B(1, 3)
            probability_caught = 0.02 * np.random.beta(1, 3, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.BETA_22:
            # # beta distribution B(2, 2)
            probability_caught = 0.01 * np.random.beta(2, 2, N)
        else:
            raise ValueError("Unexpected value specified for the probability distribution p...")


        is_caught = np.random.uniform(0, 1, N) < probability_caught
        num_caught += is_caught

        fs = compute_fs(num_caught, T)
        n = sum(fs)
        f0_hat = compute_f0(fs)
        # print(f0_hat)
        if f0_hat == 0:
            # print(fs, n, t)
            print(num_caught.sum())
        N_hat = n + f0_hat
        variance = compute_variance(fs, N_hat)
        confidence_interval = compute_confidence_inverval(n, f0_hat, variance, alpha)

        is_withing_range.append(((N >= confidence_interval[0]) and (N <= confidence_interval[1])))

        value_of_f2.append(fs[1])
        history_N_hat.append(N_hat)
        history_variance.append(variance)
        history_f0_hat.append(f0_hat)
        history_true_f0.append((num_caught == 0).sum())
        history_confidence_interval.append(confidence_interval)

    return history_N_hat, history_variance, history_f0_hat, history_true_f0, history_confidence_interval, is_withing_range, value_of_f2
    # last_step_in_range.append(is_withing_range[-1])

def simulate_with_history_multiple_runs(N: int, T: int, probability_distribution: PROBABILITY_DISTIRBUTIONS, alpha=0.05, num_runs: int = 1000):
    num_runs = 100
    all_history_N_hat = []
    all_history_variance = []
    all_history_f0_hat = []
    all_history_true_f0 = []
    all_history_confidence_interval = []
    all_is_withing_range = []
    all_value_of_f2 = []
    for run in range(num_runs):
        history_N_hat, history_variance, history_f0_hat, history_true_f0, history_confidence_interval, is_withing_range, value_of_f2 = simulate_with_history(N=N, T=T, alpha=alpha, probability_distribution=probability_distribution, verbose=False)
        # return history_N_hat, history_variance, history_f0_hat, history_true_f0, history_confidence_interval, is_withing_range, value_of_f2

        all_history_N_hat.append(history_N_hat)
        all_history_variance.append(history_variance)
        all_history_f0_hat.append(history_f0_hat)
        all_history_true_f0.append(history_true_f0)
        all_history_confidence_interval.append(history_confidence_interval)
        all_is_withing_range.append(is_withing_range)
        all_value_of_f2.append(value_of_f2)

    all_history_N_hat = np.mean(np.array(all_history_N_hat), axis=1)
    all_history_variance = np.mean(np.array(all_history_variance), axis=1)
    all_history_f0_hat = np.mean(np.array(all_history_f0_hat), axis=1)
    all_history_true_f0 = np.mean(np.array(all_history_true_f0), axis=1)
    all_history_confidence_interval = np.mean(np.array(all_history_confidence_interval), axis=1)
    all_is_withing_range = np.mean(np.array(all_is_withing_range), axis=1)
    
    return all_history_N_hat, all_history_variance, all_history_f0_hat, all_history_true_f0, all_history_confidence_interval, all_is_withing_range, all_value_of_f2

# %%
history_N_hat, history_variance, history_f0_hat, history_true_f0, history_confidence_interval, is_withing_range, value_of_f2 = simulate_with_history(N=N, T=100, alpha=alpha, probability_distribution=PROBABILITY_DISTIRBUTIONS.UNIFORM_001)
# Out:
# Simulating...: 100%|██████████| 100/100 [00:00<00:00, 3688.27it/s]

# %%
fig, ax = plt.subplots(1, 2,figsize=(16, 5))

# ax[0].plot(history_N_hat)
ax[0].set_title("Estimate of N with Variance and Confidence Interval")
ax[0].set_xlabel("Time")
ax[0].set_ylabel("Estimated N")
ax[0].plot(history_N_hat, label="Estimated $\\hat{{N}}$")

# Plot the variance upper bound but clip values above the original y-axis limits so the scale is unaffected
ymin, ymax = ax[0].get_ylim()

# Plot the confidence interval but clip values outside the original y-axis limits so the scale is unaffected
ci_lower = [max(ci[0], ymin) for ci in history_confidence_interval]
ci_upper = [min(ci[1], ymax) for ci in history_confidence_interval]
ax[0].fill_between(
    range(len(history_N_hat)),
    ci_lower,
    ci_upper,
    color="grey", alpha=0.3, label="C.I. (99%)"
)

upper_var = [n + v for n, v in zip(history_N_hat, np.sqrt(np.array(history_variance)))]
# Keep unchanged values within limits, but clip values above ymax to ymax (so they are drawn but do not affect scale)
lower_var = [n - v if n - v > 0 else 0 for n, v in zip(history_N_hat, np.sqrt(np.array(history_variance)))]
upper_var_clipped = [val if val <= ymax else ymax for val in upper_var]
ax[0].fill_between(
    range(len(history_N_hat)),
    lower_var,
    upper_var_clipped,
    color='orange', alpha=0.2, label="std."
)
# ax[0].plot(
#     upper_var_clipped,
#     'r--', alpha=0.7
# )
# ax[0].plot(
#     lower_var,
#     'b--', alpha=0.7
# )
ax[0].axhline(y=N, color='r', linestyle='--', c='black', label="True $N$")
ax[0].legend()

ax[1].plot(history_f0_hat, label="Estimated $\\hat{{f_0}}$")
ax[1].plot(history_true_f0, label="True $f_0$")
ax[1].legend()

ax[0].grid(True)
ax[1].grid(True)

# add vertical line at t=min(f_2 \neq 0)
where_f2_not_zero = np.where(np.array(value_of_f2) != 0)[0][0]
ax[0].axvline(x=where_f2_not_zero, color='r', linestyle='-', label="$f_2 > 0$")
ax[0].legend()

# fig.suptitle("Single Run")

plt.tight_layout()
plt.savefig('single_run.png', dpi=300)

plt.show()

# %% [markdown]
# ### Plots of the different probabilty density functions

# %%
X = np.linspace(0, 1, 1000)

MAX = None
Y_uniform_0_01 = np.clip(stats.uniform.pdf(X, 0, 0.01), 0, MAX)
Y_uniform_0_02 = np.clip(stats.uniform.pdf(X, 0, 0.02), 0, MAX)
Y_beta_1_3 = np.clip(stats.beta.pdf(X, 1, 3) * 0.02, 0, MAX)
Y_beta_2_2 = np.clip(stats.beta.pdf(X, 2, 2) * 0.01, 0, MAX)

Y_uniform_0_01 = Y_uniform_0_01 / Y_uniform_0_01.max()
Y_uniform_0_02 = Y_uniform_0_02 / Y_uniform_0_02.max()
Y_beta_1_3 = Y_beta_1_3 / Y_beta_1_3.max()
Y_beta_2_2 = Y_beta_2_2 / Y_beta_2_2.max()


plt.grid(True)

plt.plot(X, Y_uniform_0_01, label="U(0, 0.01)")
plt.plot(X, Y_uniform_0_02, label="U (0, 0.02)")
plt.plot(X*0.02, Y_beta_1_3, label="Beta(1, 3)")
plt.plot(X* 0.01, Y_beta_2_2, label="Beta(2, 2)")

# remove the y-axis 
# plt.gca().set_yticks([0, 0.5, 1])
plt.gca().set_yticklabels([])


plt.xlim(0, 0.03)

plt.xlabel('X')
plt.ylabel('$\\Pr(X=x)$')

plt.legend(loc='upper right')
plt.savefig('probability_density_functions.png', dpi=300)
plt.show()

# %% [markdown]
# # Monte-Carlo Simulation --- Multiple Runs

# %%
def simulate(N: int, alpha: float, seed: int, probability_distribution: PROBABILITY_DISTIRBUTIONS, T:int = 40, progress: bool = False):
    np.random.seed(seed)
    # T = 40
    # N = 1000
    # alpha = 0.01

    num_caught = np.zeros(N)

    # history_N_hat = []
    # history_variance = []
    # history_f0_hat = []
    # history_true_f0 = []
    # history_confidence_interval = []

    for t in tqdm(range(T), desc="Simulating...", disable=not progress):
        if probability_distribution == PROBABILITY_DISTIRBUTIONS.UNIFORM_001:
            # uniform U(0.0, 0.01)
            probability_caught = np.random.uniform(0, 0.01, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.UNIFORM_002:
            # # uniform U(0.0, 0.02)
            probability_caught = np.random.uniform(0, 0.02, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.BETA_13:
            # # beta distribution B(1, 3)
            probability_caught = 0.02 * np.random.beta(1, 3, N)
        elif probability_distribution == PROBABILITY_DISTIRBUTIONS.BETA_22:
            # # beta distribution B(2, 2)
            probability_caught = 0.01 * np.random.beta(2, 2, N)
        else:
            raise ValueError("Unexpected value specified for the probability distribution p")


        is_caught = np.random.uniform(0, 1, N) < probability_caught
        num_caught += is_caught

    fs = compute_fs(num_caught, T)
    n = sum(fs)
    f0_hat = compute_f0(fs)
    N_hat = n + f0_hat
    variance = compute_variance(fs, N_hat)
    confidence_interval = compute_confidence_inverval(n, f0_hat, variance, alpha)
    is_withing_range = (N >= confidence_interval[0]) and (N <= confidence_interval[1])

    return N_hat, f0_hat, variance, confidence_interval, is_withing_range

    # history_N_hat.append(N_hat)
    # history_variance.append(variance)
    # history_f0_hat.append(f0_hat)
    # history_true_f0.append((num_caught == 0).sum())
    # history_confidence_interval.append(confidence_interval)

# %%
def evaluate_data(
    N: int,
    _N_hats: List[float], 
    _f0_hats: List[float], 
    _variances: List[float], 
    # _confidence_intervals: List[Tuple[float, float]],
    _confidence_intervals_5_percent: List[Tuple[float, float]],
    _confidence_intervals_1_percent: List[Tuple[float, float]],
    _is_withing_ranges_5_percent: List[bool],
    _is_withing_ranges_1_percent: List[bool],
    _probability_distribution: PROBABILITY_DISTIRBUTIONS,
    export: str = 'table'
    ):
    N_hat_means = np.mean(_N_hats)
    N_hat_stds = np.std(_N_hats)
    f0_hat_means = np.mean(_f0_hats)
    f0_hat_stds = np.std(_f0_hats)
    variance_means = np.mean(_variances)
    variance_stds = np.std(_variances)

    # 5% confidence interval
    confidence_lower_5_percent = np.array(_confidence_intervals_5_percent)[:, 0]
    confidence_upper_5_percent = np.array(_confidence_intervals_5_percent)[:, 1]
    confidence_interval_lower_means_5_percent = np.mean(confidence_lower_5_percent)
    confidence_interval_lower_stds_5_percent = np.std(confidence_lower_5_percent)
    confidence_interval_upper_means_5_percent = np.mean(confidence_upper_5_percent)
    confidence_interval_upper_stds_5_percent = np.std(confidence_upper_5_percent)

    # 1% confidence interval
    confidence_lower_1_percent = np.array(_confidence_intervals_1_percent)[:, 0]
    confidence_upper_1_percent = np.array(_confidence_intervals_1_percent)[:, 1]
    confidence_interval_lower_means_1_percent = np.mean(confidence_lower_1_percent)
    confidence_interval_lower_stds_1_percent = np.std(confidence_lower_1_percent)
    confidence_interval_upper_means_1_percent = np.mean(confidence_upper_1_percent)
    confidence_interval_upper_stds_1_percent = np.std(confidence_upper_1_percent)

    is_withing_range_5_percent_means = np.mean(_is_withing_ranges_5_percent)
    is_withing_range_5_percentstds = np.std(_is_withing_ranges_5_percent)

    is_withing_range_1_percent_means = np.mean(_is_withing_ranges_1_percent)
    is_withing_range_1_percentstds = np.std(_is_withing_ranges_1_percent)

    bias_means = (np.mean(_N_hats) - N)**2
    bias_stds = (np.mean(_N_hats) - N)**2
    # print('Bias', bias_means, bias_stds)
    # print(np.mean(_N_hats), (np.mean(_N_hats) - N))

    # print(np.mean(bias_means), np.mean(variance_means))

    error = (np.abs(np.mean(_N_hats) - N) / N) * 100
    
    mse_mean = np.mean(bias_means + variance_means)
    mse_stds = np.std(bias_stds + variance_stds)



    data = {
        "Metric": [
            "N_hat",
            # "f0_hat",
            "Bias",
            "Error",
            "Variance",
            "Std",
            "Confidence Interval Lower (alpha=0.05)",
            "Confidence Interval Upper (alpha=0.05)",
            "Confidence Interval Lower (alpha=0.01)",
            "Confidence Interval Upper (alpha=0.01)",
            "Coverage (alpha=0.05)",
            "Coverage (alpha=0.01)",
            "MSE"
        ],
        "Mean": [
            f"{N_hat_means:.2f}",
            f"{bias_means:.2f}",
            f'{error:.2f}',
            # f"{f0_hat_means:.2f}",
            f"{variance_means:.2f}",
            f"{np.mean(np.sqrt(_variances)):.2f}",
            f"{confidence_interval_lower_means_5_percent:.2f}",
            f"{confidence_interval_upper_means_5_percent:.2f}",
            f"{confidence_interval_lower_means_1_percent:.2f}",
            f"{confidence_interval_upper_means_1_percent:.2f}",
            f"{100*is_withing_range_5_percent_means:.2f}",
            f"{100*is_withing_range_1_percent_means:.2f}",
            f"{mse_mean:.2f}"
        ],
        "Std": [
            f"{N_hat_stds:.2f}",
            f"{bias_stds:.2f}",
            0,
            # f"{f0_hat_stds:.2f}",
            f"{variance_stds:.2f}",
            f"{np.std(np.sqrt(_variances)):.2f}",
            f"{confidence_interval_lower_stds_5_percent:.2f}",
            f"{confidence_interval_upper_stds_5_percent:.2f}",
            f"{confidence_interval_lower_stds_1_percent:.2f}",
            f"{confidence_interval_upper_stds_1_percent:.2f}",
            f"{100*is_withing_range_5_percentstds:.2f}",
            f"{100*is_withing_range_1_percentstds:.2f}",
            f"{mse_stds:.2f}"
        ]
    }
    table = pd.DataFrame(data)
    table['probability_distribution'] = _probability_distribution
    table['N'] = N

    if export == 'table':
        display(table)
    elif export == 'latex':
        print(table.to_latex(index=False))
    elif export == 'dataframe':
        return table
    else:
        raise ValueError(f"Invalid export format: {export}")

# %%
def monte_carlo_simulation_and_evaluation(N: int, probability_distribution: PROBABILITY_DISTIRBUTIONS, T: int = 40) -> pd.DataFrame:

    num_runs = 1_000
    # N = 5000
    # alpha = 0.01
    N_hats, f0_hats, variances, confidence_intervals1, confidence_intervals2, is_withing_ranges1, is_withing_ranges2 = [], [], [], [], [], [], []

    for run in tqdm(range(num_runs), desc="Running Simulations...", unit="runs"):
        N_hat, f0_hat, variance, confidence_interval1, is_withing_range1 = simulate(N=N, T=T, alpha=0.05, seed=run, progress=False, probability_distribution=probability_distribution)
        N_hat, f0_hat, variance, confidence_interval2, is_withing_range2 = simulate(N=N, T=T, alpha=0.01, seed=run, progress=False, probability_distribution=probability_distribution)

        N_hats.append(N_hat)
        f0_hats.append(f0_hat)
        variances.append(variance)
        confidence_intervals1.append(confidence_interval1)
        confidence_intervals2.append(confidence_interval2)
        is_withing_ranges1.append(is_withing_range1)
        is_withing_ranges2.append(is_withing_range2)
    
    return evaluate_data(
        N=N,
        _N_hats=N_hats,
        _f0_hats=f0_hats,
        _variances=variances,
        _confidence_intervals_5_percent=confidence_intervals1,
        _confidence_intervals_1_percent=confidence_intervals2,
        _is_withing_ranges_5_percent=is_withing_ranges1,
        _is_withing_ranges_1_percent=is_withing_ranges2,
        _probability_distribution=probability_distribution,
        # export='latex'
        export='dataframe'
    )

# %%
monte_carlo_simulation_and_evaluation(N=500, probability_distribution=PROBABILITY_DISTIRBUTIONS.UNIFORM_001)
# Out:
# Running Simulations...: 100%|██████████| 1000/1000 [00:00<00:00, 1624.88runs/s]
#                                     Metric       Mean        Std  \
# 0                                    N_hat     590.45     311.27
# 1                                     Bias    8181.27    8181.27
# 2                                    Error      18.09          0
# 3                                 Variance  124464.74  902250.55
# 4                                      Std     239.58     258.97
# 5   Confidence Interval Lower (alpha=0.05)     299.68      85.80
# 6   Confidence Interval Upper (alpha=0.05)    1322.77    1298.65
# 7   Confidence Interval Lower (alpha=0.01)     250.36      59.93
# 8   Confidence Interval Upper (alpha=0.01)    1740.30    2079.01
# 9                    Coverage (alpha=0.05)      94.50      22.80
# 10                   Coverage (alpha=0.01)      99.40       7.72
# 11                                     MSE  132646.01       0.00
#
# ...

# %%
def create_huge_table(Ns: [int], probability_distribution : PROBABILITY_DISTIRBUTIONS, T: int = 40) -> pd.DataFrame:
    df = pd.DataFrame()
    for N in Ns:
        df = pd.concat([df, monte_carlo_simulation_and_evaluation(N=N, T=T, probability_distribution=probability_distribution)])
    return df

# %%
def parse_huge_table(df: pd.DataFrame) -> str:

    Ns = df['N'].unique().tolist()
    Ns.sort()

    # print(df.shape)

    def get_mean_df(_N, index: int, trim_decimal_point: bool = False, space_thousands: bool = False):
        if trim_decimal_point:
            if space_thousands:
                return f'{int(df[df['N'] == _N]["Mean"].values[index].split('.')[0]):,}'.replace(',', '\\ ')
            return f'{df[df['N'] == _N]["Mean"].values[index].split('.')[0]}'
        return f'{df[df['N'] == _N]["Mean"].values[index]}'

    def get_mean_and_std_df(_N, index: int):
        return f'{df[df['N'] == _N]["Mean"].values[index]} \\variance{{{df[df['N'] == _N]['Std'].values[index].split('.')[0]}}}'


    def get_n_hat(_N):
        # return f"{df[df['N'] == _N]['Mean'].values[0]} \\variance {{{df[df['N'] == _N]['Std'].values[0].split('.')[0]}}}"
        return get_mean_and_std_df(_N, 0)

    def get_error(_N):
        # return f"{df[df['N'] == _N]['Mean'].values[2]}"
        return get_mean_df(_N, 2)

    def get_sigma(_N):
        return get_mean_and_std_df(_N, 4)
        # return f"{df[df['N'] == _N]['Mean'].values[4]} \\variance{{{df[df['N'] == _N]['Std'].values[4]}}}"

    def get_coverage(_N, alpha: float):
        if alpha == 0.05:
            return get_mean_and_std_df(_N, 9)
            # return f"{df[df['N'] == _N]['Mean'].values[9]} \\variance{{{df[df['N'] == _N]['Std'].values[9]}}}"
        elif alpha == 0.01:
            return get_mean_and_std_df(_N, 10)
            # return f"{df[df['N'] == _N]['Mean'].values[10]}"
        else:
            raise ValueError(f"Invalid alpha: {alpha}")

    def get_bias(_N):
        return get_mean_df(_N, 1, trim_decimal_point=True, space_thousands=True)

    def get_variance(_N):
        return get_mean_df(_N, 3, trim_decimal_point=True, space_thousands=True)

    def get_mse(_N):
        return get_mean_df(_N, 11, trim_decimal_point=True, space_thousands=True)

    def get_ci(_N, alpha: float):
        if alpha == 0.05:
            # return f"[{df[df['N'] == _N]['Mean'].values[5]} \\variance{{{df[df['N'] == _N]['Std'].values[5]}}}; {df[df['N'] == _N]['Mean'].values[6]} \\variance{{{df[df['N'] == _N]['Std'].values[6]}}}]"
            return f"[{get_mean_and_std_df(_N, 5)}; {get_mean_and_std_df(_N, 6)}]"
        elif alpha == 0.01:
            return f"[{get_mean_and_std_df(_N, 7)}; {get_mean_and_std_df(_N, 8)}]"
            # return f"[{df[df['N'] == _N]['Mean'].values[7]} \\variance{{{df[df['N'] == _N]['Std'].values[7]}}}; {df[df['N'] == _N]['Mean'].values[8]} \\variance{{{df[df['N'] == _N]['Std'].values[8]}}}]"
        else:
            raise ValueError(f"Invalid alpha: {alpha}")

    latex_table = f"""\\begin{{table}}[t]
    \\centering 
    \\caption*{{$p_i \\sim U(0, 0.01)$}}
    \\begin{{tabular}}{{c c|c c c}}
        \\toprule
        & & \\multicolumn{{1}}{{|c|}}{{${{N}}={Ns[0]}$}} & \\multicolumn{{1}}{{c|}}{{${{N}}={Ns[1]}$}} & \\multicolumn{{1}}{{c}}{{${{N}}={Ns[2]}$}} \\\\
        \\midrule
        \\multicolumn{{2}}{{c|}}{{${{\\hat{{\\mathbf{{N}}}}}}$}} & ${get_n_hat(Ns[0])}$ & ${get_n_hat(Ns[1])}$ & ${get_n_hat(Ns[2])}$  \\\\
        \\multicolumn{{2}}{{c|}}{{\\textbf{{Error}} (\\%)}} & ${get_error(Ns[0])}$ & ${get_error(Ns[1])}$ & ${get_error(Ns[2])}$ \\\\
        % \\hline
        \\multicolumn{{2}}{{c|}}{{${{\\hat{{\\mathbf{{\\sigma}}}}}}_{{\\hat{{N}}}}$}} & ${get_sigma(Ns[0])}$ & ${get_sigma(Ns[1])}$ & ${get_sigma(Ns[2])}$\\\\
        % \\hline
        \\multirow{{2}}{{*}}{{\\textbf{{C.I.}}}} & $\\alpha = 0.05$ & ${get_ci(Ns[0], 0.05)}$ & ${get_ci(Ns[1], 0.05)}$ & ${get_ci(Ns[2], 0.05)}$
        \\\\
        % 
        & $\\alpha = 0.01$ & ${get_ci(Ns[0], 0.01)}$ & ${get_ci(Ns[1], 0.01)}$ & ${get_ci(Ns[2], 0.01)}$ \\\\
        \\midrule
        \\multirow{{2}}{{*}}{{\\textbf{{Coverage}} (\\%)}} & $\\alpha = 0.05$ & ${get_coverage(Ns[0], 0.05)}$ & ${get_coverage(Ns[1], 0.05)}$ & ${get_coverage(Ns[2], 0.05)}$ \\\\
        & $\\alpha = 0.01$ & ${get_coverage(Ns[0], 0.01)}$ & ${get_coverage(Ns[1], 0.01)}$ & ${get_coverage(Ns[2], 0.01)}$ \\\\
        \\multicolumn{{2}}{{c|}}{{\\textbf{{Bias}} ($\\approx$)}} & ${get_bias(Ns[0])}$ & ${get_bias(Ns[1])}$ & ${get_bias(Ns[2])}$ \\\\
        \\multicolumn{{2}}{{c|}}{{\\textbf{{Variance}} ($\\approx$)}} & ${get_variance(Ns[0])}$ & ${get_variance(Ns[1])}$ & ${get_variance(Ns[2])}$ \\\\
        \\multicolumn{{2}}{{c|}}{{\\textbf{{MSE}} ($\\approx$)}} & ${get_mse(Ns[0])}$ & ${get_mse(Ns[1])}$ & ${get_mse(Ns[2])}$ \\\\
        \\bottomrule
    \\end{{tabular}}
    \\caption{{Result from $1000$ MC simulations for estimating $\\hat{{N}}$. For each value, we report on the mean (black) and standard deviation (gray). We omit the digits after the decimal point for the standard deviation for brevity.
    The Error (\\%) is the absolute difference between the estimated and the true value of $N$, divided by the true value of $N$.}}
    \\label{{tab:problem_2_results}}
\\end{{table}}"""

    print(latex_table)

# %% [markdown]
# ### $U(0, 0.01)$

# %%
# for U(0, 0.01)
df_huge = create_huge_table(Ns=[500, 1000, 5000], probability_distribution=PROBABILITY_DISTIRBUTIONS.UNIFORM_001)
parse_huge_table(df_huge)
# Out:
# ...
# Running Simulations...: 100%|██████████| 1000/1000 [00:02<00:00, 371.84runs/s]
# \begin{table}[t]
#     \centering
#     \caption*{$p_i \sim U(0, 0.01)$}
#     \begin{tabular}{c c|c c c}
#         \toprule
#         & & \multicolumn{1}{|c|}{${N}=500$} & \multicolumn{1}{c|}{${N}=1000$} & \multicolumn{1}{c}{${N}=5000$} \\
#         \midrule
#         \multicolumn{2}{c|}{${\hat{\mathbf{N}}}$} & $590.45 \variance{311}$ & $1096.62 \variance{286}$ & $5152.14 \variance{583}$  \\
#         \multicolumn{2}{c|}{\textbf{Error} (\%)} & $18.09$ & $9.66$ & $3.04$ \\
#         % \hline
#         \multicolumn{2}{c|}{${\hat{\mathbf{\sigma}}}_{\hat{N}}$} & $239.58 \variance{258}$ & $284.17 \variance{116}$ & $566.36 \variance{98}$\\
#         % \hline
#         \multirow{2}{*}{\textbf{C.I.}} & $\alpha = 0.05$ & $[299.68 \variance{85}; 1322.77 \variance{1298}]$ & $[687.34 \variance{137}; 1842.05 \variance{609}]$ & $[4179.35 \variance{423}; 6414.78 \variance{804}]$
#         \\
#         %
# ...

# %% [markdown]
# ### $U(0, 0.02)

# %%
# for U(0, 0.02)
df_huge = create_huge_table(Ns=[500, 1000, 5000], probability_distribution=PROBABILITY_DISTIRBUTIONS.UNIFORM_002)
parse_huge_table(df_huge)
# Out:
# ...
# Running Simulations...: 100%|██████████| 1000/1000 [00:02<00:00, 368.89runs/s]
# \begin{table}[t]
#     \centering
#     \caption*{$p_i \sim U(0, 0.01)$}
#     \begin{tabular}{c c|c c c}
#         \toprule
#         & & \multicolumn{1}{|c|}{${N}=500$} & \multicolumn{1}{c|}{${N}=1000$} & \multicolumn{1}{c}{${N}=5000$} \\
#         \midrule
#         \multicolumn{2}{c|}{${\hat{\mathbf{N}}}$} & $527.70 \variance{98}$ & $1035.16 \variance{134}$ & $5088.17 \variance{284}$  \\
#         \multicolumn{2}{c|}{\textbf{Error} (\%)} & $5.54$ & $3.52$ & $1.76$ \\
#         % \hline
#         \multicolumn{2}{c|}{${\hat{\mathbf{\sigma}}}_{\hat{N}}$} & $97.71 \variance{29}$ & $133.04 \variance{27}$ & $288.03 \variance{25}$\\
#         % \hline
#         \multirow{2}{*}{\textbf{C.I.}} & $\alpha = 0.05$ & $[381.03 \variance{57}; 774.58 \variance{172}]$ & $[818.85 \variance{91}; 1347.52 \variance{198}]$ & $[4568.45 \variance{240}; 5700.59 \variance{337}]$
#         \\
#         %
# ...

# %% [markdown]
# ### Beta(1, 3)

# %%
# for Beta(1, 3)
df_huge = create_huge_table(Ns=[500, 1000, 5000], probability_distribution=PROBABILITY_DISTIRBUTIONS.BETA_13)
parse_huge_table(df_huge)
# Out:
# ...
# Running Simulations...:  32%|███▏      | 324/1000 [00:04<00:08, 79.84runs/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[277], line 2
#       1 # for Beta(1, 3)
# ----> 2 df_huge = create_huge_table(Ns=[500, 1000, 5000], probability_distribution=PROBABILITY_DISTIRBUTIONS.BETA_13)
#       3 parse_huge_table(df_huge)
#
# Cell In[273], line 4, in create_huge_table(Ns, probability_distribution, T)
#       2 df = pd.DataFrame()
#       3 for N in Ns:
# ----> 4     df = pd.concat([df, monte_carlo_simulation_and_evaluation(N=N, T=T, probability_distribution=probability_distribution)])
#       5 return df
#
# Cell In[271], line 10, in monte_carlo_simulation_and_evaluation(N, probability_distribution, T)
#       8 for run in tqdm(range(num_runs), desc="Running Simulations...", unit="runs"):
# ...

# %% [markdown]
# ### Beta(2, 2)

# %%
# for Beta(2, 2)
df_huge = create_huge_table(Ns=[500, 1000, 5000], T=80, probability_distribution=PROBABILITY_DISTIRBUTIONS.BETA_22)
parse_huge_table(df_huge)
# Out:
# ...
# Running Simulations...: 100%|██████████| 1000/1000 [00:31<00:00, 31.69runs/s]
# \begin{table}[t]
#     \centering
#     \caption*{$p_i \sim U(0, 0.01)$}
#     \begin{tabular}{c c|c c c}
#         \toprule
#         & & \multicolumn{1}{|c|}{${N}=500$} & \multicolumn{1}{c|}{${N}=1000$} & \multicolumn{1}{c}{${N}=5000$} \\
#         \midrule
#         \multicolumn{2}{c|}{${\hat{\mathbf{N}}}$} & $517.55 \variance{100}$ & $1022.24 \variance{129}$ & $5057.81 \variance{290}$  \\
#         \multicolumn{2}{c|}{\textbf{Error} (\%)} & $3.51$ & $2.22$ & $1.16$ \\
#         % \hline
#         \multicolumn{2}{c|}{${\hat{\mathbf{\sigma}}}_{\hat{N}}$} & $95.08 \variance{31}$ & $130.52 \variance{27}$ & $285.44 \variance{26}$\\
#         % \hline
#         \multirow{2}{*}{\textbf{C.I.}} & $\alpha = 0.05$ & $[374.85 \variance{57}; 757.81 \variance{181}]$ & $[809.99 \variance{88}; 1328.62 \variance{193}]$ & $[4542.75 \variance{244}; 5664.70 \variance{345}]$
#         \\
#         %
# ...

# %% [markdown]
# ### Test for longer Time steps

# %%
# for U(0, 0.01)
df_huge = create_huge_table(Ns=[500, 1000, 5000], probability_distribution=PROBABILITY_DISTIRBUTIONS.UNIFORM_001)
parse_huge_table(df_huge)

# %%
# expected value for n
def expected_value_n(N: int, T: int, p: float) -> float:
    return N * ( 1 - (1-p) ** T)

data = []

T = 40
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Expected value for n: {expected_value_n(N, T, p)}")
        data.append({
            'N': N,
            'N_hat': expected_value_n(N, T, p),
            'p': p
        })
df_expected_small_n = pd.DataFrame(data)
# Out:
# N: 500; p: 0.01; Expected value for n: 165.51412071515986
# N: 500; p: 0.005; Expected value for n: 90.83993948866286
# N: 1000; p: 0.01; Expected value for n: 331.0282414303197
# N: 1000; p: 0.005; Expected value for n: 181.67987897732573
# N: 5000; p: 0.01; Expected value for n: 1655.1412071515986
# N: 5000; p: 0.005; Expected value for n: 908.3993948866287

# %% [markdown]
# ### Probability for $P(f_2 = 0)$

# %%
def probability_f2_eq_0(N: int, T: int, p: float) -> float:
    return (
        1.0 - stats.binom.pmf(2, T, p)
    ) ** N

# %%
T = 40
data = []
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Expected value for n: {probability_f2_eq_0(N, T, p)}")
        data.append({
            'N': N,
            'p': p,
            'probability_f2_eq_0': probability_f2_eq_0(N, T, p)
        })

df_probability_f2_eq_0 = pd.DataFrame(data)
# Out:
# N: 500; p: 0.01; Expected value for n: 1.3186228002851456e-12
# N: 500; p: 0.005; Expected value for n: 0.0002961442553238478
# N: 1000; p: 0.01; Expected value for n: 1.738766089431839e-24
# N: 1000; p: 0.005; Expected value for n: 8.770141996131635e-08
# N: 5000; p: 0.01; Expected value for n: 1.5892997259829723e-119
# N: 5000; p: 0.005; Expected value for n: 5.1883961108275926e-36

# %%
T = 40
data = []
for T in range(1, 40):
    for N in [500, 1000, 5000]:
        for p in [0.01, 0.005]:
            # print(f"N: {N}; p: {p}; Expected value for n: {probability_f2_eq_0(N, T, p)}")
            result = {}
            result['N'] = N
            result['p'] = p
            result['t'] = T
            result['probability_f2_eq_0'] = probability_f2_eq_0(N, T, p)
            data.append(result)

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
df = pd.DataFrame(data)
sns.lineplot(data=df[df['p'] == 0.01], x='t', y='probability_f2_eq_0', hue='N', ax=ax[0], palette='tab10')
sns.lineplot(data=df[df['p'] == 0.005], x='t', y='probability_f2_eq_0', hue='N', ax=ax[1], palette='tab10')
# df = pd.DataFrame(data)
# df
ax[1].legend()
ax[0].legend()

ax[1].grid(True)
ax[0].grid(True)

ax[0].set_title('p = 0.01')
ax[1].set_title('p = 0.005')

df_probability_f2_eq_0_over_time = df.copy()

plt.savefig('probability_f2_eq_0.png')
plt.show()

# %% [markdown]
# ### $\mathbb{E}[\hat{f_0} \mid f_2 = 0, T=t]$

# %%
def expected_value_f0_f2_eq_0(N: int, T: int, p: float) -> float:
    total = 0.0
    for n in range(N):
        total += ((n**2 - n)/2.0) * stats.binom.pmf(n, N, stats.binom.pmf(1, T, p))
    return total

# %%
T = 40
data = []
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Expected value for f_0: {expected_value_f0_f2_eq_0(N, T, p)}")
# Out:
# N: 500; p: 0.01; Expected value for f_0: 9113.93056496853
# N: 500; p: 0.005; Expected value for f_0: 3375.2103473630546
# N: 1000; p: 0.01; Expected value for f_0: 36492.25103969364
# N: 1000; p: 0.005; Expected value for f_0: 13514.369286636007
# N: 5000; p: 0.01; Expected value for f_0: 913036.8515887321
# N: 5000; p: 0.005; Expected value for f_0: 338129.790109578

# %%
T = 40
data_f0_time = []
for T in range(1, 40):
    for N in [500, 1000, 5000]:
        for p in [0.01, 0.005]:
            # print(f"N: {N}; p: {p}; Expected value for n: {probability_f2_eq_0(N, T, p)}")
            result = {}
            result['N'] = N
            result['p'] = p
            result['t'] = T
            result['probability_f2_eq_0'] = expected_value_f0_f2_eq_0(N, T, p)
            data_f0_time.append(result)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
df_f0_time = pd.DataFrame(data_f0_time)
sns.lineplot(data=df_f0_time[df_f0_time['p'] == 0.01], x='t', y='probability_f2_eq_0', hue='N', ax=ax[0], palette='tab10')
sns.lineplot(data=df_f0_time[df_f0_time['p'] == 0.005], x='t', y='probability_f2_eq_0', hue='N', ax=ax[1], palette='tab10')

df_expected_small_n_p01 = df_expected_small_n[df_expected_small_n['p'] == 0.01]
for i, _N in enumerate([500, 1000, 5000]):
    f0 = _N - df_expected_small_n_p01[df_expected_small_n_p01['N'] == _N]['N_hat'].values[0]
    print(f0)
    ax[0].hlines(y=f0, xmin=0, xmax=40, color=sns.color_palette('tab10')[i], linestyle='--', label='$500-\\mathbb{E}[n\\mid N=500]$')

ax[1].set_yscale('log')
ax[0].set_yscale('log')

ax[1].legend()
ax[0].legend()

ax[1].grid(True)
ax[0].grid(True)

ax[0].set_title('p = 0.01')
ax[1].set_title('p = 0.005')

plt.savefig('expectation_f0_f2_eq_0.png')
plt.show()
# Out:
# 334.48587928484017
# 668.9717585696803
# 3344.858792848401

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# df = pd.DataFrame(data)

df_f0_time_rescaled = df_f0_time.copy()
df_f0_time_rescaled['p'] = df_f0_time_rescaled['p'] * df_probability_f2_eq_0_over_time['p'] 

sns.lineplot(data=df[df['p'] == 0.01], x='t', y='probability_f2_eq_0', hue='N', ax=ax[0], palette='tab10')
sns.lineplot(data=df[df['p'] == 0.005], x='t', y='probability_f2_eq_0', hue='N', ax=ax[1], palette='tab10')

df_expected_small_n_p01 = df_expected_small_n[df_expected_small_n['p'] == 0.01]
for i, _N in enumerate([500, 1000, 5000]):
    f0 = _N - df_expected_small_n_p01[df_expected_small_n_p01['N'] == _N]['N_hat'].values[0]
    print(f0)
    ax[0].hlines(y=f0, xmin=0, xmax=40, color=sns.color_palette('tab10')[i], linestyle='--', label=f'${_N}-\\mathbb{{E}}[n\\mid N=500]$')

ax[1].set_yscale('log')
ax[0].set_yscale('log')

ax[1].legend()
ax[0].legend()

ax[1].grid(True)
ax[0].grid(True)

ax[0].set_title('p = 0.01')
ax[1].set_title('p = 0.005')

plt.savefig('expectation_f0_f2_eq_0_rescaled.png')
plt.show()
# Out:
# 334.48587928484017
# 668.9717585696803
# 3344.858792848401

# %% [markdown]
# ### Covariance f_1 f_2

# %%
def covariance_f1_f2(N: int, T: int, p: float) -> float:
    return -N * stats.binom.pmf(1, T, p) * stats.binom.pmf(2, T, p)
    # &= -N \cdot \mathrm{Binomial}(T, 1, p) \cdot \mathrm{Binomial}(T, 2, p)

# %%
T = 40
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Expected value for f_0: {covariance_f1_f2(N, T, p)}")
# Out:
# N: 500; p: 0.01; Expected value for f_0: -7.1950626917222955
# N: 500; p: 0.005; Expected value for f_0: -1.3255979652486831
# N: 1000; p: 0.01; Expected value for f_0: -14.390125383444591
# N: 1000; p: 0.005; Expected value for f_0: -2.6511959304973662
# N: 5000; p: 0.01; Expected value for f_0: -71.95062691722295
# N: 5000; p: 0.005; Expected value for f_0: -13.255979652486833

# %%
def correlation_f1_f2(N: int, T: int, p: float) -> float:
    covariance = -N * stats.binom.pmf(1, T, p) * stats.binom.pmf(2, T, p)
    variance_f1 = N * stats.binom.pmf(1, T, p) * (1 - stats.binom.pmf(1, T, p))
    variance_f2 = N * stats.binom.pmf(2, T, p) * (1 - stats.binom.pmf(2, T, p))
    return covariance / np.sqrt(variance_f1 * variance_f2)
T = 40
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Correlation: {correlation_f1_f2(N, T, p)}")
# Out:
# N: 500; p: 0.01; Correlation: -0.14432364921726468
# N: 500; p: 0.005; Correlation: -0.05679010371798132
# N: 1000; p: 0.01; Correlation: -0.14432364921726468
# N: 1000; p: 0.005; Correlation: -0.05679010371798132
# N: 5000; p: 0.01; Correlation: -0.14432364921726465
# N: 5000; p: 0.005; Correlation: -0.056790103717981336

# %% [markdown]
# ### $\mathbb{E}[\hat{f_0} \mid f_2 > 0, T=t]$

# %%
def expected_value_f0_f2_gt_0(N: int, T: int, p: float) -> float:
    # return -N * stats.binom.pmf(1, T, p) * stats.binom.pmf(2, T, p)
    total = 0.0
    for n in tqdm(range(N-1)):
        for m in range(1, N-n+1):
            total += ((n**2)/(2*m)) * stats.binom.pmf(n, N, stats.binom.pmf(1, T, p)) * stats.binom.pmf(n, N, stats.binom.pmf(2, T, p))
    return total

# %%
# * I was maybe a bit too optimistic for computing this expected value


# T = 40
# for N in [500, 1000, 5000]:
#     for p in [0.01, 0.005]:
#         print(f"N: {N}; p: {p}; Correlation: {expected_value_f0_f2_gt_0(N, T, p)}")
# Out:
# N: 500; p: 0.01; Correlation: 8.826488473621571e-20
# N: 500; p: 0.005; Correlation: 3.7309723748121097e-17
# N: 1000; p: 0.01; Correlation: 4.827555141124375e-41
# N: 1000; p: 0.005; Correlation: 3.179147162516961e-35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 4
#       2 for N in [500, 1000, 5000]:
#       3     for p in [0.01, 0.005]:
# ----> 4         print(f"N: {N}; p: {p}; Correlation: {expected_value_f0_f2_gt_0(N, T, p)}")
#
# Cell In[55], line 6, in expected_value_f0_f2_gt_0(N, T, p)
#       4 for n in range(N-1):
#       5     for m in range(1, N-n+1):
# ----> 6         total += ((n**2)/(2*m)) * stats.binom.pmf(n, N, stats.binom.pmf(1, T, p)) * stats.binom.pmf(n, N, stats.binom.pmf(2, T, p))
#       7 return total
#
# ...

# %% [markdown]
# ### Skewness

# %%
def skewness_fi(N: int, T: int, p: float, i: int) -> float:
    nominator = 1 - 2 * stats.binom.pmf(i, T, p)
    denominator = N * (stats.binom.pmf(i, T, p) * (1-stats.binom.pmf(i, T, p)))
    denominator = np.sqrt(denominator)
    return nominator / denominator

T = 40
for N in [500, 1000, 5000]:
    for p in [0.01, 0.005]:
        print(f"N: {N}; p: {p}; Skewness: {skewness_fi(N, T, p, 2)}")
# Out:
# N: 500; p: 0.01; Skewness: 0.17798519444679195
# N: 500; p: 0.005; Skewness: 0.3436822475086931
# N: 1000; p: 0.01; Skewness: 0.12585453794413284
# N: 1000; p: 0.005; Skewness: 0.2430200477868303
# N: 5000; p: 0.01; Skewness: 0.05628386042398153
# N: 5000; p: 0.005; Skewness: 0.10868186934931996

# %% [markdown]
# # $\mathbb{E}[X_i\mid T=40]$

# %%
def expected_number_of_times_caught(T: int, p: float):
    total = 0.0

    for k in range(T):
        # total += k * comb(T, k) * (p**k) * ((1-p)**(T-k))
        p_x = comb(T, k) * (p**k) * ((1-p)**(T-k))
        # total += p_x
        total += p_x * k
        # print("K:", k, "; P(X=k) * k:", p_x * k, "; total:", total)

    return total

# %%
# for U(0, 0.01)
p = 0.01
expected_number_of_times_caught(40, p)
# Out:
# np.float64(0.3999999999999997)

# %%
# for U(0, 0.02)
p = 0.02
expected_number_of_times_caught(40, p)
# Out:
# np.float64(0.7999999999999995)
